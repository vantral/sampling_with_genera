# %% [markdown]
# # Parsing Glottolog

# %%
from pathlib import Path
from tqdm.notebook import tqdm
import glob
import pandas as pd
from anytree import Node, RenderTree, NodeMixin
from anytree.search import findall
from itertools import combinations
import bibtexparser
import re

import configparser
config = configparser.RawConfigParser()

# %% [markdown]
# Getting all `.ini` files that are stored in `glottolog/langoids/tree/` with all information on anitem

# %%
paths = []

for path in tqdm(glob.glob('../glottolog/languoids/tree/**/*', recursive=True)):
    if path.endswith('.ini'):
        paths.append(Path(path))
# Out:
#   0%|          | 0/53346 [00:00<?, ?it/s]

# %% [markdown]
# Getting all the data for all nodes. Important: if run on Windows, make sure `LongsPathEnabled` if set to 1.

# %%
mds = []

for path in tqdm(paths):
#     print(path)
    config = configparser.RawConfigParser()
    config.read(path, encoding='utf8')
    md = {s: dict(config[s].items()) for s in config.sections()}
    dct = {
        'glottocode': path.parts[-2],
        'path': Path(*path.parts[3:-1]).as_posix(),
        'toplevelfamily': path.parts[4]
    }
#     if 'core' not in md:
#         print(md)
    core = md['core'].copy()
    dct.update(core)
    del md['core']
    dct['other'] = md
    mds.append(dct)
# Out:
#   0%|          | 0/26673 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 6
#       3 for path in tqdm(paths):
#       4 #     print(path)
#       5     config = configparser.RawConfigParser()
# ----> 6     config.read(path, encoding='utf8')
#       7     md = {s: dict(config[s].items()) for s in config.sections()}
#       8     dct = {
#       9         'glottocode': path.parts[-2],
#      10         'path': Path(*path.parts[3:-1]).as_posix(),
#      11         'toplevelfamily': path.parts[4]
#      12     }
#
# File ~\anaconda3\Lib\configparser.py:683, in RawConfigParser.read(self, filenames, encoding)
#     681 for filename in filenames:
#     682     try:
# --> 683         with open(filename, encoding=encoding) as fp:
#     684             self._read(fp, filename)
#     685     except OSError:
#
# File <frozen codecs>:309, in __init__(self, errors)
#
# KeyboardInterrupt:

# %% [markdown]
# Saving all data and filtering only languages (excluding families).

# %%
md_data = pd.DataFrame(mds)
md_data.to_csv("all_data_from_glottolog.csv")

raw_languages_data = md_data[md_data.level == 'language']
language_list = raw_languages_data.glottocode.to_list()

# %% [markdown]
# Getting sources

# %%
sources = raw_languages_data.other.tolist()

# %%
sources = [x['sources']['glottolog'].strip('\n *') if 'sources' in x else '' for x in sources]

# %% [markdown]
# Reading `hh.bib`.

# %%
libraries = {}
with open('../glottolog/references/bibtex/hh.bib', encoding='utf8') as f:
    libraries['hh'] = bibtexparser.load(f)
# Out:
# Entry type pdhthesis not standard. Not considered.

# %%
libraries['hh'].entries[0]
# Out:
# {'macro_area': 'Eurasia',
#  'lgcode': 'Tati, Harzani [hrz]',
#  'inlg': 'Farsi [pes]',
#  'hhtype': 'grammar_sketch',
#  'glottolog_ref_id': '41999',
#  'year': '1334 [1953]',
#  'pages': '6+160',
#  'address': 'Tabriz',
#  'publisher': 'Tabriz: Tabriz University Press',
#  'title': 'Tāti va Harzani, do lahja az zabān-i bāstān-e Āẕarbāyjān',
#  'author': "'Abd-al-'Ali Kārang",
#  'ENTRYTYPE': 'book',
#  'ID': 's:Karang:Tati-Harzani'}

# %%
def find_entry(library_name, key, libraries):
    """
    finding entry by library_name, key and libraries
    """
    for entry in libraries[library_name].entries:
        if entry['ID'] == key:
            return entry

# %%
def find_pages_and_inlg_of_grammar(entry):
    """
    pages and language by entry
    """
    pages = None
    inlg = None
    for field in entry.keys():
        if field == 'pages':
            pages = entry[field]
        if field == 'inlg':
            inlg = entry[field]
        if field == 'hhtype':
            if 'grammar' not in entry[field]:
                return None, None
    return pages, inlg

# %%
def string2int(numeric):
    """
    Converting different types of string-encoded numerals to int
    """
    numeric = numeric.strip()
    if not numeric:
        return 0
    if numeric.isdigit():
        return int(numeric)
    if '-' in numeric:
        start, end = numeric.split('-', 1)
        return string2int(end) - string2int(start) + 1
    if '+' in numeric:
        parts_plus = numeric.split('+')
        return sum([string2int(x) for x in parts_plus])
    rom_val = {'i': 1, 'v': 5, 'x': 10, 'l': 50, 'c': 100, 'd': 500, 'm': 1000}
    int_val = 0
    for i in range(len(numeric)):
        if i > 0 and rom_val[numeric[i]] > rom_val[numeric[i - 1]]:
            int_val += rom_val[numeric[i]] - 2 * rom_val[numeric[i - 1]]
        else:
            int_val += rom_val[numeric[i]]
    return int_val

# %%
def count_pages(string_pages: str):
    """
    Counting pages
    """
    parts_comma = re.split(r'[,;] ?', string_pages)
    for i, part in enumerate(parts_comma):
        part = part.replace('–', '-')
        part = re.sub(r'\(.*?\)', '', part).strip()
        part = re.sub(r'(?:plates?|ff?|S\.|pp|\+? ?map|tables|\?|\[|\])', '', part).strip()
        parts_comma[i] = string2int(part)
    return sum(parts_comma)

# %%
name
# Out:
# 'typ:Ko:Crow'

# %%
sources_pages = []
sources_langs = []
for source in tqdm(sources):
    n_pages = []
    for entry in source.split('**\n**'):
        if not entry:
            continue
        library, name = entry.split(':', 1)
        
        if library != 'hh':
            continue
            
        entry = find_entry(library, name, libraries)
        if not entry:
            continue
        pages, inlg = find_pages_and_inlg_of_grammar(entry)
        
        if not pages:
            continue
            
        try:
            n_pages.append(count_pages(pages))
        except:
            if pages:
                n_pages.append(pages)
    sources_pages.append(n_pages)
    sources_langs.append(inlg)
# Out:
#   0%|          | 0/8565 [00:00<?, ?it/s]

# %%
raw_languages_data.loc[:, 'pages'] = sources_pages
raw_languages_data.loc[:, 'inlg'] = sources_langs
# Out:
# C:\Users\vantral\AppData\Local\Temp\ipykernel_13216\335294811.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_languages_data.loc[:, 'pages'] = sources_pages
# C:\Users\vantral\AppData\Local\Temp\ipykernel_13216\335294811.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_languages_data.loc[:, 'inlg'] = sources_langs

# %%
raw_languages_data.to_csv('languages_with_pages_v05.11.2024.tsv', sep='\t')

# %%
raw_languages_data = pd.read_csv('languages_with_pages_v05.11.2024.tsv', sep='\t')
md_data = pd.read_csv("all_data_from_glottolog.csv")

# %%
genera = pd.read_csv('genera.tsv', delimiter='\t')

# %%
genera = genera[~pd.isna(genera.confidence)]

# %%
genera = pd.merge(
    genera,
    raw_languages_data
)[['glottocode', 'genus', 'name', 'toplevelfamily', 'pages', 'confidence']]

# %%
polina = "Arawakan, Nuclear-Macro-Je, Tucanoan, Chapacuran, Chocoan, Matacoan, Lengua-Mascoy, Yanomamic, Guahiboan, Guaicuruan, Chonan, Naduhup, Saliban, Zamucoan, Boran, Hibito-Cholon, Uru-Chipaya, Andoque, Betoi-Jirara, Hoti, Itonama, Kanoê, Movima, Kariri, Mosetén-Chimané, Páez, Puinave, Pumé"
families = polina.split(', ')
families_codes = md_data[md_data.name.isin(families)].toplevelfamily.unique()

# %%
names_codes = md_data[md_data.name.isin(families)][['toplevelfamily', 'name']].drop_duplicates()
families_mapping = {k:v for k, v in zip(names_codes.toplevelfamily, names_codes.name)}
families_mapping
# Out:
# {'ando1256': 'Andoque',
#  'araw1281': 'Arawakan',
#  'beto1236': 'Betoi-Jirara',
#  'bora1262': 'Boran',
#  'chap1271': 'Chapacuran',
#  'choc1280': 'Chocoan',
#  'chon1288': 'Chonan',
#  'guah1252': 'Guahiboan',
#  'guai1249': 'Guaicuruan',
#  'hibi1242': 'Hibito-Cholon',
#  'iton1250': 'Itonama',
#  'kano1245': 'Kanoê',
#  'kari1254': 'Kariri',
#  'leng1261': 'Lengua-Mascoy',
#  'mata1289': 'Matacoan',
#  'mose1249': 'Mosetén-Chimané',
#  'movi1243': 'Movima',
#  'nada1235': 'Naduhup',
#  'nucl1710': 'Nuclear-Macro-Je',
#  'paez1247': 'Páez',
#  'puin1248': 'Puinave',
#  'pume1238': 'Pumé',
#  'sali1297': 'Saliban',
#  'tuca1253': 'Tucanoan',
#  'uruc1242': 'Uru-Chipaya',
#  'yano1268': 'Yanomamic',
#  'yuwa1244': 'Hoti',
#  'zamu1243': 'Zamucoan'}

# %%
genera_for_polia = genera[genera.toplevelfamily.isin(families_codes)][['genus', 'toplevelfamily']].drop_duplicates()

# %%
genera_for_polia
# Out:
#                     genus toplevelfamily
# 417               isolate       ando1256
# 440          Alto-Orinoco       araw1281
# 443       Japura-Colombia       araw1281
# 445    Antillean Arawakan       araw1281
# 448     Guajiro-Paraujano       araw1281
# 450      Central Arawakan       araw1281
# 457               Palikur       araw1281
# 469         Negro-Roraima       araw1281
# 479        Bolivia-Parana       araw1281
# 486   Pre-Andine Arawakan       araw1281
# 497              Yanesha'       araw1281
# 498                 Purus       araw1281
# 3032              isolate       beto1236
# 3035                Boran       bora1262
# 3180     Chapacura-Wanham       chap1271
# 3216                Choco       choc1280
# 3225        Chonan Proper       chon1288
# 3442             Guahiban       guah1252
# 3447               Abipon       guai1249
# 3448                  Qom       guai1249
# 3451              Kadiwéu       guai1249
# 4014              isolate       iton1250
# 4060              isolate       kano1245
# 4214             Mascoian       leng1261
# 4334             Matacoan       mata1289
# 4437              isolate       mose1249
# 4438              isolate       movi1243
# 4447              Nadahup       nada1235
# 4898               Jabutí       nucl1710
# 4900           Je Central       nucl1710
# 4904        Je Meridional       nucl1710
# 4907      Je Setentrional       nucl1710
# 4914               Karajá       nucl1710
# 4915               Aimore       nucl1710
# 4916           Maxakalian       nucl1710
# 4919            Rikbaktsa       nucl1710
# 5107              isolate       paez1247
# 5408              isolate       puin1248
# 5409              isolate       pume1238
# 5502          Maco-Piaroa       sali1297
# 5504               Sáliba       sali1297
# 6313             Tucanoan       tuca1253
# 6514          Uru-Chipaya       uruc1242
# 6628              Yanomam       yano1268
# 6656             Zamucoan       zamu1243

# %%
genera_for_polia['toplevelfamily'] = genera_for_polia['toplevelfamily'].apply(lambda x: families_mapping[x])

# %%
genera['pages'] = genera.pages.apply(eval)

# %%
pages_by_genera = genera.groupby('genus')[['pages']].aggregate(lambda x: sum(x, []))
pages_mapping = dict(pages_by_genera['pages'].apply(lambda x: natsorted(x, reverse=True)))

# %%
genera_for_polia['pages'] = genera_for_polia.genus.apply(lambda x: pages_mapping[x] if x != 'isolate' else '')

# %%
genera_for_polia
# Out:
#                     genus    toplevelfamily  \
# 417               isolate           Andoque
# 440          Alto-Orinoco          Arawakan
# 443       Japura-Colombia          Arawakan
# 445    Antillean Arawakan          Arawakan
# 448     Guajiro-Paraujano          Arawakan
# 450      Central Arawakan          Arawakan
# 457               Palikur          Arawakan
# 469         Negro-Roraima          Arawakan
# 479        Bolivia-Parana          Arawakan
# 486   Pre-Andine Arawakan          Arawakan
# 497              Yanesha'          Arawakan
# 498                 Purus          Arawakan
# 3032              isolate      Betoi-Jirara
# 3035                Boran             Boran
# 3180     Chapacura-Wanham        Chapacuran
# 3216                Choco           Chocoan
# 3225        Chonan Proper            Chonan
# 3442             Guahiban         Guahiboan
# 3447               Abipon        Guaicuruan
# 3448                  Qom        Guaicuruan
# 3451              Kadiwéu        Guaicuruan
# 4014              isolate           Itonama
# 4060              isolate             Kanoê
# 4214             Mascoian     Lengua-Mascoy
# 4334             Matacoan          Matacoan
# 4437              isolate   Mosetén-Chimané
# 4438              isolate            Movima
# 4447              Nadahup           Naduhup
# 4898               Jabutí  Nuclear-Macro-Je
# 4900           Je Central  Nuclear-Macro-Je
# 4904        Je Meridional  Nuclear-Macro-Je
# 4907      Je Setentrional  Nuclear-Macro-Je
# 4914               Karajá  Nuclear-Macro-Je
# 4915               Aimore  Nuclear-Macro-Je
# 4916           Maxakalian  Nuclear-Macro-Je
# 4919            Rikbaktsa  Nuclear-Macro-Je
# 5107              isolate              Páez
# 5408              isolate           Puinave
# 5409              isolate              Pumé
# 5502          Maco-Piaroa           Saliban
# 5504               Sáliba           Saliban
# 6313             Tucanoan          Tucanoan
# 6514          Uru-Chipaya       Uru-Chipaya
# 6628              Yanomam         Yanomamic
# 6656             Zamucoan          Zamucoan
#
#                                                   pages
# 417
# 440          [245, 236, 216, 98, 92, 69, 40, 26, 15, 6]
# 443   [1089, 729, 543, 482, 479, 384, 381, 374, 328,...
# 445   [536, 462, 396, 323, 313, 313, 306, 296, 293, ...
# 448   [708, 582, 352, 322, 268, 224, 204, 204, 179, ...
# 450   [603, 480, 458, 297, 244, 211, 122, 118, 110, ...
# 457                                     [256, 109, 102]
# 469                                     [298, 179, 148]
# 479   [1034, 893, 644, 500, 223, 206, 192, 136, 127,...
# 486   [895, 709, 701, 502, 487, 412, 394, 366, 335, ...
# 497                            [288, 283, 154, 116, 66]
# 498        [705, 477, 412, 261, 208, 207, 140, 119, 17]
# 3032
# 3035             [583, 388, 333, 224, 132, 132, 84, 20]
# 3180                                     [530, 320, 62]
# 3216  [336, 295, 272, 227, 208, 176, 175, 170, 166, ...
# 3225  [488, 481, 371, 238, 216, 149, 124, 107, 99, 5...
# 3442  [918, 798, 461, 439, 436, 312, 254, 141, 137, ...
# 3447                                [367, 356, 176, 60]
# 3448  [577, 558, 409, 329, 329, 320, 290, 274, 252, ...
# 3451                       [291, 200, 176, 142, 84, 74]
# 4014
# 4060
# 4214                   [818, 356, 334, 128, 90, 82, 62]
# 4334  [637, 574, 542, 517, 469, 343, 342, 306, 293, ...
# 4437
# 4438
# 4447    [1134, 1006, 706, 484, 346, 337, 272, 222, 101]
# 4898                                          [157, 10]
# 4900             [508, 331, 281, 228, 228, 202, 14, 14]
# 4904  [314, 284, 263, 243, 219, 211, 123, 82, 58, 47...
# 4907  [445, 366, 359, 317, 299, 269, 266, 255, 247, ...
# 4914                      [301, 90, 77, 66, 61, 42, 30]
# 4915                              [315, 93, 26, 24, 18]
# 4916                                [328, 144, 131, 70]
# 4919                                [387, 108, 103, 27]
# 5107
# 5408
# 5409
# 5502                                 [589, 330, 33, 12]
# 5504                        [263, 142, 118, 52, 37, 22]
# 6313  [929, 725, 602, 557, 536, 528, 514, 513, 500, ...
# 6514  [330, 327, 238, 221, 123, 84, 50, 37, 37, 36, 11]
# 6628  [779, 440, 346, 240, 234, 122, 120, 116, 78, 7...
# 6656                        [146, 133, 133, 59, 51, 45]

# %%
genera_for_polia.to_excel('genera_for_polia_with_pages.xlsx')

# %%
from natsort import natsorted

# %%
genera.pages = genera.pages.apply(lambda x: natsorted(x, reverse=True))

# %%
for key, df in genera.groupby('genus'):
    sorted_df = df.sort_values('pages', ascending=False)
    sorted_df.to_excel(f'genera/{key.strip("|=")[:30]}.xlsx', index=False)

# %%
print('\n'.join(sorted(genera.genus.unique())))
# Out:
# =|Hoan
# Abau
# Abipon
# Achumawi
# Agneby
# Aimore
# Ainu
# Alacalufan
# Aleut
# Algonquian
# Alor-Pantar
# Alto-Orinoco
# Amuzgoan
# Angaataha
# Angami-Pochuri
# Anindilyakwa
# Antillean Arawakan
# Ap Ma
# Arauan
# Araucanian
# Arhuacic
# Arikem
# Armenian
# Aslian
# Asmat-Kamrau Bay
# Atayalic
# Athapaskan
# Atsugewi
# Avar-Andic-Tsezic
# Avikam-Alladian
# Awju
# Aymaran
# Aztecan
# Baatonum
# Bahnaric
# Baibai-Fas
# Baining
# Baltic
# Bantu
# Barbacoan
# Bargam
# Barito
# Barí
# Batanic
# Beboid
# Becking-Dawi
# Beja
# Bella Coola
# Benue-Congo Plateau
# Berber
# Bilic
# Binanderean
# Birri
# Biu-Mandara
# Boazi
# Bodic
# Bogia
# Bolivia-Parana
# Bongo-Bagirmi
# Boran
# Border
# Bororoan
# Bosavi
# Brahmaputran
# Bringen
# Bua
# Bulaka River
# Bunuban
# Burarran
# Burmese-Lolo
# Cacua-Nukak
# Caddo
# Cahita
# Cahuapanan
# Cangin
# Cariban
# Catawban
# Celebic
# Celtic
# Central Arawakan
# Central Cushitic
# Central Delta
# Central Kainji
# Central Luzon
# Central Malayo-Polynesian
# Central Naga
# Central Pama-Nyungan
# Central Salish
# Central Tariku
# Central Wapei
# Chamorro
# Chapacura-Wanham
# Chibcha-Duit
# Chichimec
# Chimakuan
# Chimbu-Wahgi
# Chimila
# Chinantecan
# Chinese
# Chinookan
# Chiquitano
# Choco
# Chonan Proper
# Chumash
# Coosan
# Corachol
# Core Goilalan
# Creoles and Pidgins
# Dagan
# Dahalo
# Daju
# Dani
# Dargwic
# Day
# Defoid
# Dhimalic
# Digaroan
# Dizoid
# Djingili
# Dogon
# Dravidian
# Dumut
# East Bird's Head
# East Chadic
# East Formosan
# East Strickland
# East Tariku
# East Timor
# East Wapei
# Eastern Daly
# Eastern Gunwinyguan
# Eastern Jebel
# Eastern Mande
# Eastern Nilotic
# Eastern Pauwasi
# Eastern Saharan
# Eastern Trans-Fly
# Edoid
# Ega
# Egyptian-Coptic
# Ekoid-Mbe
# Eleman
# Elevala
# Enga_Kewa-Huli
# Enggano
# Eskimo
# Eyak
# Finisterre
# Finnic
# Foe
# Fore-Gimi
# Fur
# Ga-Dangme
# Gade
# Gahuku
# Garrwan
# Gauwa
# Gbaya-Manza-Ngbaka
# Gbe
# Geelvink Bay
# Germanic
# Gogodala
# Gola
# Great Andamanese
# Greater Central Philippine
# Greek
# Grusi
# Guahiban
# Guajiro-Paraujano
# Guaymiic
# Guhu-Samane
# Gumuz
# Haida
# Harakmbet
# Hatim-Mansim
# Heiban
# Highland East Cushitic
# Himalayish
# Hlai
# Hmongic
# Huarpe
# Huavean
# Huon
# Idomoid
# Igboid
# Ijoid
# Inanwatan
# Indic
# Interior Salish
# Iranian
# Isirawa
# Iwaidjan
# Iwamic
# Jaad
# Jabutí
# Jaminjungan
# Japanese
# Japura-Colombia
# Jarrakan
# Javanese
# Je Central
# Je Meridional
# Je Setentrional
# Jivaroan
# Jola
# Josephstaal
# Ju-Kung
# Jukunoid
# Ka-Togo
# Kadai
# Kadiwéu
# Kadugli
# Kalam-Kobon
# Kalapuyan
# Kam-Tai
# Kanum
# Karajá
# Karbic
# Karen
# Kariri
# Kartvelian
# Katla-Tima
# Katuic
# Katukinan
# Kaure
# Kayagar
# Keresan
# Khasian
# Khinalug
# Khmer
# Khmuic
# Kho-Bwa
# Khoe-Kwadi
# Kim
# Kiowa-Tanoan
# Kirma-Tyurama
# Kiwaian
# Kman-Meyor
# Koiarian
# Kolopom
# Koman
# Kombio-Arapesh
# Korean
# Koromfe
# Kowan
# Kresh
# Krisa
# Kru
# Kuki-Chin
# Kuliak
# Kuna
# Kwerba
# Kwomtari
# Lak
# Lampungic
# Land Dayak
# Left May
# Lendu
# Lezgic
# Limilngan
# Lobiri-Jaane
# Lower Cross
# Lower Ramu
# Lower Sepik
# Lowland East Cushitic
# Maban
# Mabuso
# Maco-Piaroa
# Macro-Bai
# Maiduan
# Mailuan
# Mairasic
# Majang
# Malayo-Sumbawan
# Mamfe
# Mandan
# Mangarrayi
# Mangbetu
# Mangbutu-Efe
# Manipuri
# Manjaku
# Mara
# Mari
# Marienberg
# Marind-Yaqay
# Marne
# Masa
# Mascoian
# Matacoan
# Matlatzincan
# Maweti-Guarani
# Maxakalian
# Mayan
# Mbumic
# Mek
# Mienic
# Minahasan
# Mississippi Valley Siouan
# Missouri River Siouan
# Misumalpan
# Miwok
# Mixe-Zoque
# Mixtec
# Mombum
# Monde
# Mongolic
# Monic
# Mordvin
# Moru-Ma'di
# Mumuye-Yandang
# Munda
# Munduruku
# Murrinh-Patha
# Muskogean
# Na-Qiangic
# Na-Togo
# Nadahup
# Nakh
# Nakkara
# Nambikuaran
# Ndjébbana
# Ndu
# Negro-Roraima
# Ngankikurungkurr
# Nicobarese
# Nimboran
# Nivkh
# North Adelbert
# North Borneo
# North Bougainville
# North Halmaheran
# Northern Caddoan
# Northern Chukotko-Kamchatkan
# Northern Daly
# Northern Iroquoian
# Northern Luzon
# Northern Mel
# Northern Pama-Nyungan
# Northern Uto-Aztecan
# Northern Wakashan
# Northwest Caucasian
# Northwest Sumatra-Barrier Islands
# Nubian
# Nuclear Angan
# Nukuma
# Nunggubuyu
# Nungish
# Nupoid
# Nuristani
# Nyimang
# Nyulnyulan
# Oceanic
# Ogonoid
# Ohio Valley Siouan
# Ok
# Oksapmin
# Opata-Eudeve
# Oti-Volta
# Otomian
# Paiwan
# Palauan
# Palaungic
# Palikur
# Pamean
# Paniai Lakes
# Panoan
# Pearic
# Peba-Yaguan
# Pech
# Permic
# Peul-Serer
# Piawi
# Pomoan
# Popolocan
# Pre-Andine Arawakan
# Purus
# Qom
# Quechuan
# Rai Coast
# Raji-Raute
# Ram
# Rama
# Ramarama
# Rao
# Rashad
# Rejang
# Rikbaktsa
# Romance
# Ruboni
# Rukai
# Saami
# Sahaptian
# Sama-Bajaw
# Samba-Duru
# Samoyedic
# Sangiric
# Semitic
# Senagi
# Sentanic
# Senufo
# Sepik Hill
# Serra Hills
# Shasta
# Siane-Yagaria
# Sign Languages
# Slavic
# Sogeram
# Somahai
# Songhay
# South Andamanese
# South Bird's Head Proper
# South Bougainville
# South Halmahera - West New Guinea
# South Omotic
# South Sulawesi
# South Surmic
# Southeastern Pama-Nyungan
# Southern Chukotko-Kamchatkan
# Southern Cushitic
# Southern Iroquoian
# Southern Mel
# Southern Nilotic
# Southern Wakashan
# Subtiaba-Tlapanec
# Suki
# Sáliba
# Ta-Ne-Omotic
# Tacanan
# Tairora
# Talodi
# Tama Sepik
# Taman
# Tangkhul-Maring
# Tangkic
# Tani
# Tano
# Tarahumaran
# Tarascan
# Taulil
# Teberan
# Temein
# Tenda
# Tepiman
# Tequistlatecan
# Ticuna
# Tikar
# Tillamook
# Tivoid
# Tlingit
# Tol
# Tor-Orya
# Totonacan
# Trique
# Tsamosan
# Tsimshianic
# Tsou
# Tu
# Tubar
# Tucanoan
# Tunebo
# Tungusic
# Tupari
# Turama-Kikorian
# Turkic
# Tusia
# Ubangi
# Ugric
# Upper Cross
# Urat
# Urim
# Uru-Chipaya
# Vietic
# Wagaydy
# Wambayan
# Wappo
# Warapu
# West Bird's Head
# West Bomberai
# West Chadic
# West Palei
# West Tariku
# West Wapei
# Western Gunwinyguan
# Western Isthmic Chibchan
# Western Mande
# Western Nilotic
# Western Pama-Nyungan
# Western Plains Austronesian
# Western Saharan
# Western Skou
# Wide Grassfields
# Wintuan
# Witoto
# Wiyot
# Wogamusin-Chenapian
# Wolof
# Worrorran
# Yanesha'
# Yangmanic
# Yanomam
# Yapese
# Yareban
# Yawa
# Yei
# Yellow River
# Yeniseian
# Yokuts
# Yukaghir
# Yuki
# Yuman
# Yurok
# Yuruna
# Zamucoan
# Zaparoan
# Zapotecan
# Zemeic
# isolate

# %%
class NodeWithGenus(NodeMixin):
    def __init__(self, name, genus=None, parent=None, confidence=None):
        self.name = name
        self.genus = genus
        self.parent = parent
        self.md = md
        self.confidence = confidence
    def __repr__(self):
        return f'Node {self.name}, Genus {self.genus}'

def find_common_ancestor(node1, node2):
    anc1 = list(node1.ancestors)
    anc2 = list(node2.ancestors)
    
    anc1.reverse()
    anc2.reverse()
    
    for i in anc1:
        for j in anc2:
            if i == j:
                return i

# %%
wals = pd.read_csv('wals_languages.csv')
wals.at[2296,'Glottocode'] = 'shah1254'
genera = wals[['Genus', 'Glottocode']].dropna()
genera = pd.Series(genera.Genus.values,index=genera.Glottocode).to_dict()

# %%
wals.query('Genus == "Yaruro"')
# Out:
#        ID    Name      Macroarea  Latitude  Longitude Glottocode ISO639P3code  \
# 2614  yrr  Yaruro  South America       7.0      -68.0   pume1238          yae
#
#       Family Subfamily   Genus GenusIcon ISO_codes Samples_100 Samples_200  \
# 2614  Yaruro       NaN  Yaruro       NaN       yae       False       False
#
#      Country_ID               Source     Parent_ID
# 2614         VR  Mosonyi-et-al-2000a  genus-yaruro

# %%
nodes = {}
lst = [path.split('/') for path in md_data.path]

for path in lst:
    for i, par in enumerate(path):
        nk = nodes[par] = nodes.get(par) or NodeWithGenus(par, genera.get(par, None))
        if i != 0:
            nv = nodes[path[i - 1]] = nodes.get(path[i - 1]) or NodeWithGenus(path[i - 1], genera.get(path[i - 1], None))
            nk.parent = nv
            
[root] = [n for n in nodes.values() if n.parent is None]

# %%
leaves = root.descendants

for leaf in leaves:
    if leaf.genus:
        leaf.confidence = 'initial'
    if leaf.parent == root:
        leaf.genus = 'isolate'

# %%
for genus in tqdm(wals.Genus.dropna().unique()):
    if genus in ['Creoles and Pidgins', 'Sign Languages']:
        continue
    # Creoles and Pidgins as well as Sign Languages do not form a genealogical genus
    
    langs = findall(root, filter_=lambda node: node.genus == genus)
    # Find all languages with the same genus
    
    print(genus, len(langs))
    
    pairs = combinations(langs, 2)
    # Make all possible combinations
    
    all_nodes = list(root.descendants)
    
    for node1, node2 in pairs:
        anc = find_common_ancestor(node1, node2)
        # find the first common ancestor
        
        if anc.name in ['uncl1493', 'book1242']:
            continue
        
        # if an ancestor has already been taken into account it is removed from the list
        if anc not in all_nodes:
            continue
        else:
            all_nodes.remove(anc)
        
        for des in anc.descendants:
            if des.genus and des.genus != genus:
                # if any descendant has another genus, nothing is changed
                break
        else:
            for des in anc.descendants:
                if des.genus:
                    continue
                des.genus = genus
                des.confidence = f'common ancestor ({node1.name}, {node2.name})'

# %%
for node in tqdm(root.descendants):
    if node.name not in language_list:
        continue
    if node.parent.name in ['uncl1493', 'root', 'book1242']:
        continue
    if not node.genus or node.genus in ['Creoles and Pidgins', 'Sign Languages']:
        continue
    # Creoles and Pidgins as well as Sign Languages do not form a genealogical genus
    
    siblings = node.siblings
    
    for sibling in siblings:
        if sibling.genus and sibling.genus != node.genus:
            # if any sibling has another genus, nothing is changed
            break
    else:
        for sibling in siblings:
            if sibling.genus or sibling.name not in language_list:
                continue
            sibling.genus = node.genus
            sibling.confidence = f'sibling of {node.name}'

# %%
leaves = root.descendants

# %%
leaves = [leaf for leaf in leaves if leaf.name in language_list]

# %%
len(leaves)

# %%
sum([x.genus is not None for x in leaves])

# %%
7134 / 8578

# %%
final_df = [
    {
        'glottocode': x.name,
        'genus': x.genus,
        'confidence': x.confidence
    } for x in leaves
]

# %%
pd.DataFrame(final_df)#.query('glottocode == "tari1263"')

# %%
pd.DataFrame(final_df).to_csv('genera.tsv', sep='\t', index=False)
